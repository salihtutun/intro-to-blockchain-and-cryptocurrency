# %% [markdown]
# # Session 12 — If this left the classroom, what license?
#
# This is the **practice notebook**. Fill every `YOUR TURN` (`???`) while we work on the class notebook. `???` will not run until you replace it. That is on purpose. There is no answer key here.
#
# If a word is fuzzy, open `site/handbook.html` for this session (about 10 minutes of pictures). Then come back.
#
# We stay on **testnet**. This is a fire drill: pretend real humans paid
# real money.
#
# Law is fact-heavy. We learn **questions**, not "I am your lawyer."

# %% [markdown]
# ## Words we use today
#
# Read this once. If a later cell uses the word, come back here.
#
# | Word | In this class it means |
# |---|---|
# | **Legal object** | Voucher, deposit, security-like sale — facts, not the ticker. |
# | **Howey-shaped facts** | Public sale + profit pitch + “we will work the price” is the danger zone. |
# | **Travel Rule** | Name + account travel with the payment, like a wire. Crypto is not the nameless pipe. |
# | **Build / partner / pass** | Ship it yourselves, hire a licensed rail, or do not do this live. |
# | **Utility-token tweet** | A label. Labels do not win. Facts win. |

# %% [markdown]
# ## Pictures for legal objects
#
# **Carnival ride ticket.** You buy it to ride = **voucher**. Poster says
# "this ticket will 10x when we list on eBay" → starts to look like
# "invest in our hustle" (Howey-shaped facts).
#
# **Starbucks card.** Stored value. Lots of real-world rules. Still not a
# share of Starbucks.
#
# **Venmo to a cousin.** Banks send **name + account** with a wire. The
# Travel Rule is "please don't make crypto the one pipe with no name."
#
# **"Utility token" tweet.** Labels do not win. Facts win.
#
# **A6 checklist**
# - Legal object
# - Howey-style facts that help or hurt
# - Licenses you would *investigate*
# - Custody partner *type*
# - Who puts the name on the wire
# - One feature you will **not** ship
# - One sentence you will **not** tweet
#
# **Slow walk — two posters.**
# Poster A: “1 EAGE = one cookie at office hours. Not for sale to strangers.”
# Closed voucher. Still not mainnet. Still not legal advice.
# Poster B: “Buy EAGE tonight — we will list it and it 10xes.”
# Sold to the public + profit pitch + team working the price → **Howey-shaped**.
# The cookie can still exist. The *pitch* is what changed the object.
#
# Classroom scoring (not law): public sale +2, profit pitch +3, team-works-price +2.
# Score ≥ 5 → cut the pitch before you write A6.

# %% [markdown]
# ### Keep this straight
#
# **If you remember one thing.** Facts classify the object. A ticker and a tweet do not.
#
# **Common mix-up.** “It’s a utility token” as a complete answer. Say what a stranger can *do* with it.
#
# **Why Eagecoin cares.** A6 needs: legal object, Howey facts, licenses to *investigate*, custody partner *type*, who names the wire, one feature you will not ship, one sentence you will not tweet.

# %%
# YOUR TURN -- classify YOUR coin. All values True/False.

facts = {
    "sold_to_public": ???,
    "profit_pitch": ???,
    "team_will_work_on_price": ???,
    "redeem_for_a_real_good": ???,
    "one_to_one_fiat_reserve": ???,
}

score = 0
if facts["sold_to_public"]:
    score += 2
if facts["profit_pitch"]:
    score += 3
if facts["team_will_work_on_price"]:
    score += 2
print("facts", facts, "score", score)
if score >= 5:
    print("classroom vibe: MIXED / security-like -- cut the pitch")
elif facts["redeem_for_a_real_good"] and not facts["sold_to_public"]:
    print("classroom vibe: closed voucher -- still no mainnet")
else:
    print("classroom vibe: messy -- write A6 slowly")

# %% [markdown]
# ## Exit
#
# The marketing sentence you refuse to use. Say it so you never type it.
# Still testnet.

# %% [markdown]
# ## Check you understand (say it out loud)
#
# 1. Which three facts push a carnival ticket toward Howey-shaped?
# 2. What does the Travel Rule want to travel with the payment?
# 3. Build, partner, or pass — pick one for *your* coin if it left the lab tomorrow, and name the missing license.
#
# If an answer is a slogan (“decentralized,” “web3,” “the future of money”),
# you do not understand it yet. Open the **concept handbook**
# (`student-files/site/handbook.html` — or `handbook.html` on the course site)
# and rewrite the answer with a cafeteria, key, or lemonade picture.

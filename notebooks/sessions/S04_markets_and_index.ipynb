# %% [markdown]
# # Session 4 — Markets: prices, a tiny index, how people get coins
#
# This is the **practice notebook**. Fill every `YOUR TURN` (`???`) while we work on the class notebook. `???` will not run until you replace it. That is on purpose. There is no answer key here.
#
# If a word is fuzzy, open `site/handbook.html` for this session (about 10 minutes of pictures). Then come back.
#
# A coin nobody will hold overnight is a club sticker, not money.
#
# By the end: read a price, meet **index** and **beta**, and tell
# wallet vs ETF vs exchange app apart as **packages**.

# %% [markdown]
# ## Words we use today
#
# Read this once. If a later cell uses the word, come back here.
#
# | Word | In this class it means |
# |---|---|
# | **Price** | What one coin costs in CLASSUSD (or punches in dollars) *right now*. |
# | **Index** | A playlist of coins. One number for “the tape.” |
# | **Beta** | A dance partner: if the playlist jumps 1%, this coin *tends* to jump β%. |
# | **Spot / wallet** | You hold the thing. You are *in* the concert. |
# | **ETF** | You own a share of a company that holds seats for clients. |
# | **Exchange tab** | A merch-stand IOU. The company may owe you the coin. |
# | **Airdrop / sale / earn** | Gift / ticket booth / wage — three different legal and social objects. |

# %% [markdown]
# ## Pictures
#
# **Price.** 1 punch = $3 at the door. Tomorrow 1 punch = $0.10 → you printed
# too many or nobody wants pizza.
#
# **Index.** A playlist of coins. **Beta** of 2: when the playlist jumps 1%,
# your coin *tends* to jump ~2%. A habit in the data, not a seatbelt.
#
# **Concert packages**
# - **Wallet / spot:** you are *in* the room (you hold the thing).
# - **ETF:** you own a company that holds seats for clients.
# - **Exchange tab:** you have a merch-stand IOU.
#
# Same concert energy. Three legal objects.
#
# **Distribution is a financial object**
#
# | Method | School picture | Feels like |
# |---|---|---|
# | Airdrop | Teacher hands everyone 10 tickets | A gift |
# | Sale for CLASSUSD | Ticket booth | A sale (and maybe a security if you hype 10x) |
# | Earn | 10 minutes of tutoring → 2 coins | A wage |
#
# **PoS in one breath.** Bitcoin security ≈ energy. PoS security ≈ coins that
# can be **slashed** if a validator cheats.
#
# **Slow walk — same concert, three tickets.**
# Ava wants “Bitcoin exposure.”
# 1. She buys BTC into MetaMask → she holds BTC (wallet / spot).
# 2. She buys a spot-Bitcoin ETF → she holds a *fund share* (custody + prospectus).
# 3. She sees “0.1 BTC” in a trading app → she may only hold an IOU.
#
# If the app dies, (1) still works if she has the seed, (2) is a securities claim,
# (3) is a customer-in-line story. **Do not grade them as the same object.**
#
# **Beta is not a seatbelt.** β = 2 on five handmade days is a habit in *this*
# tiny sample. It does not promise tomorrow.

# %% [markdown]
# ### Keep this straight
#
# **If you remember one thing.** How you *get* the coin (airdrop, sale, earn) is a financial object, not a vibe.
#
# **Common mix-up.** “Listed on an exchange” = “I hold the coin.” Often you hold a tab.
#
# **Why Eagecoin cares.** Freeze ticker and distribution before Remix. Selling EAGE for CLASSUSD *plus* a 10× pitch is how you wander into Howey-shaped facts later.

# %%
# YOUR TURN -- beta with a tiny handmade playlist (no wifi needed).
# When the "market" moves, ETH-like moves a lot, SPY-like barely.

market = [0.02, -0.01, 0.03, 0.00, -0.02]   # crypto playlist returns
ethish = [0.04, -0.02, 0.06, 0.01, -0.03]   # dances harder
spyish = [0.01, 0.00, 0.01, 0.00, -0.01]    # sleepy

def beta(asset, market):
    n = len(asset)
    ma = sum(asset) / n
    mm = sum(market) / n
    cov = sum((a - ma) * (m - mm) for a, m in zip(asset, market)) / (n - 1)
    var = sum((m - mm) ** 2 for m in market) / (n - 1)
    return cov / var

print("ETH-like beta:", ???)   # beta(ethish, market)
print("SPY-like beta:", ???)
print("A beta is a dance partner, not a promise.")

# %% [markdown]
# ## Exit
#
# Would a classmate hold *your* coin overnight? Yes/no + one reason about
# **use**, not hope. Freeze ticker/name for A2.

# %% [markdown]
# ## Check you understand (say it out loud)
#
# 1. In one sentence: what is beta *not*?
# 2. Wallet vs ETF vs exchange tab — which one is self-custody?
# 3. Name your distribution method: airdrop, sale, or earn. Why that one?
#
# If an answer is a slogan (“decentralized,” “web3,” “the future of money”),
# you do not understand it yet. Open the **concept handbook**
# (`student-files/site/handbook.html` — or `handbook.html` on the course site)
# and rewrite the answer with a cafeteria, key, or lemonade picture.

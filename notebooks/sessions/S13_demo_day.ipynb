# %% [markdown]
# # Session 13 — Demo day
#
# This is the **practice notebook**. Fill every `YOUR TURN` (`???`) while we work on the class notebook. `???` will not run until you replace it. That is on purpose. There is no answer key here.
#
# If a word is fuzzy, open `site/handbook.html` for this session (about 10 minutes of pictures). Then come back.
#
# Eight minutes. Circulation first. Vibes never.
#
# **Projector order**
# 1. Contract (network, cap, roles)
# 2. A classmate **not on your team** holding it
# 3. A pool quote
# 4. A transfer and a redemption (hash on screen)
# 5. Then: problem → what broke → **go / partner / pass**

# %% [markdown]
# ## Words we use today
#
# Read this once. If a later cell uses the word, come back here.
#
# | Word | In this class it means |
# |---|---|
# | **Unbundle** | Which pieces did this use case actually need? Database vs chain, registrar vs consensus, token vs escrow. |
# | **Go** | A licensed fintech should build this piece. |
# | **Partner** | Buy or rent a licensed rail. Do not pretend you are the rail. |
# | **Pass** | This should not leave the lab. An A-level ending if you can say it with evidence. |
# | **Live proof** | Hash, stranger holder, quote — not a slide about “community.” |

# %% [markdown]
# ## Unbundle — the MIT question in teen English
#
# | Need | School tool | What people blindly grab |
# |---|---|---|
# | A list of who has what | Shared spreadsheet | "We need a blockchain" |
# | Only Ava can approve Ava's spend | Locker key | A whole new Layer-1 |
# | A posted cap on tickets | Google Form max=30 | Token + chain + AMM |
#
# Answer out loud:
# 1. Did we need a chain, or a database?
# 2. Did we need consensus, or a trusted registrar?
# 3. Did we need a token, or an escrow tab?
#
# **Room rules**
# - Testnet explorer only. No seed phrases.
# - Every teammate speaks.
# - A7 was due at the start. Do not read it aloud. Point at hashes.
#
# If your coin circulated and you can say **pass** with a straight face,
# that is an A-level ending.

# %% [markdown]
# ### Keep this straight
#
# **If you remember one thing.** Hashes first, recommendation last. Vibes never.
#
# **Common mix-up.** Reading the memo aloud instead of pointing at a stranger’s balance and a tx.
#
# **Why Eagecoin cares.** Eight minutes: contract → stranger → quote → transfer/redeem → go/partner/pass.

# %%
# YOUR TURN -- fill the live-proof card BEFORE you stand up.

contract_network = "???"
contract_address = "???"
stranger_name = "???"          # not on your team
pool_quote = "???"
live_tx = "???"
recommendation = "???"         # go / partner / pass
backup_line = "If MetaMask dies we open the log in the first 15 seconds."

print("1. Contract", contract_network, contract_address)
print("2. Stranger", stranger_name)
print("3. Quote", pool_quote)
print("4. Tx", live_tx)
print("5. Rec", recommendation)
print(backup_line)

# %% [markdown]
# ## Check you understand (say it out loud)
#
# 1. Say the five live proofs in order without looking.
# 2. Database vs chain: which did *your* use case actually need?
# 3. Go, partner, or pass — one word, then the missing license or the thing that broke.
#
# If an answer is a slogan (“decentralized,” “web3,” “the future of money”),
# you do not understand it yet. Open the **concept handbook**
# (`student-files/site/handbook.html` — or `handbook.html` on the course site)
# and rewrite the answer with a cafeteria, key, or lemonade picture.

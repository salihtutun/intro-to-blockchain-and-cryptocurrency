# %% [markdown]
# # A8 — Demo day run-of-show
#
# Print this, put it next to the laptop, do not design 19 slides.

# %% [markdown]
# ## Words we use today
#
# Read this once. If a later cell uses the word, come back here.
#
# | Word | In this class it means |
# |---|---|
# | **Live proof order** | Contract → stranger holder → quote → transfer/redeem → recommendation. |
# | **Stranger** | A classmate not on your team. Teammate balances do not count. |
# | **Backup line** | If MetaMask dies, open the log in the first 15 seconds. |

# %% [markdown]
# Handbook § S13. Eight minutes. Sit down at 8:00.

# %%
# ===== fill the night before =====
contract = {
    "network": "Sepolia",
    "address": "0x...",
    "cap": 10_000,
    "minter": "0x...",
    "pauser": "0x...",
}
stranger_holder = {"name": "classmate not on our team", "address": "0x...", "balance": 200}
pool_quote = "0.50 CLASSUSD per TEAM (2000 / 1000) — refresh live"
live_tx = "0x... transfer"
live_redeem = "0x... or photo of minutes delivered"
backup_line = "If MetaMask dies: we open the circulation log in the first 15 seconds."
recommendation = "pass / partner / go"
who_speaks = [
    ("Person A", "problem + mechanism"),
    ("Person B", "live proofs"),
    ("Person C", "what broke + recommendation"),
]

print("PROJECTOR ORDER")
print("1. Contract", contract)
print("2. Stranger", stranger_holder)
print("3. Quote", pool_quote)
print("4. Tx", live_tx, "| redeem", live_redeem)
print("5. Rec", recommendation)
print(backup_line)
print("\nSPEAKING MAP")
for person, job in who_speaks:
    print(f"  {person}: {job}")
print("\nNo seeds. No mainnet. Sit down at 8:00.")

# %% [markdown]
# ## Rehearsal (3 times)
#
# 1. Once with wifi. 2. Once as if MetaMask is dead. 3. Once with a mean question:
#    "Did you need a blockchain?"
#
# If you cannot answer that with the unbundle sentence, go back to A7 section 5.

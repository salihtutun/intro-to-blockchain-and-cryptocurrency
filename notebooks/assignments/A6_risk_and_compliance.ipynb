# %% [markdown]
# # A6 — Risk + "what if we left the lab"
#
# Part 1 uses Session 11 and L3.
# Part 2 is a fire drill. Still **testnet**.

# %% [markdown]
# ## Words we use today
#
# Read this once. If a later cell uses the word, come back here.
#
# | Word | In this class it means |
# |---|---|
# | **Kill criteria** | IF number THEN action. “We’ll watch” is not a rule. |
# | **Peg / run** | Poster price vs Saturday rush at one door. |
# | **Howey-shaped facts** | Public sale + profit pitch + “we work the price.” |
# | **Build / partner / pass** | Ship, rent a licensed rail, or do not go live. |

# %% [markdown]
# Handbook § S11 (gift-card run) and § S12 (two posters). Still testnet.

# %%
# ===== three risks you actually have =====
risks = [
    ("admin key", "one laptop holds minter+pauser", "second pauser / hardware backup"),
    ("liquidity", "thin CLASSUSD bowl, wild quotes", "kill: pause if depth < 50 CLASSUSD"),
    ("redemption", "we might flake on tutoring", "public office-hour calendar + burn-on-show"),
]

print("TOP RISKS")
for kind, story, mitigation in risks:
    print(f"- [{kind}] {story}\n    own this: {mitigation}")

kill_criteria = [
    "IF |price-0.50|/0.50 > 0.40 AND depth < 50 CLASSUSD THEN pause transfers",
    "IF a redemption waits > 7 days THEN stop mint",
    "IF owner key might be leaked THEN pause and rotate (procedure)",
]
print("\nKILL CRITERIA")
for k in kill_criteria:
    print(" -", k)

# %%
# ===== launch checklist (hypothetical real world) =====
checklist = {
    "legal_object": "closed voucher / time-bank — not a 10x investment",
    "howey_facts_hurt_if": "we sell to strangers and tweet listing dreams",
    "licenses_to_investigate": "money transmission / e-money / securities — home country",
    "custody_partner_type": "qualified custodian or we stay self-serve + tiny caps",
    "travel_rule": "we would need names on transfers above a threshold — vendor TBD",
    "will_not_ship_v1": "public sale, mainnet, price talk",
    "will_not_tweet": "EAGE will 10x when we list",
}

print("IF THIS LEFT THE LAB")
for k, v in checklist.items():
    print(f"{k}: {v}")
print("\nStill testnet. Do not deploy to mainnet because a memo felt brave.")

# %% [markdown]
# # A5 — Claim + netting
#
# Two jobs:
# 1. Write what the token **stands for** (coat check vs the coat).
# 2. Cancel a **triangle of debts** like lunch-table Venmo.

# %% [markdown]
# ## Words we use today
#
# Read this once. If a later cell uses the word, come back here.
#
# | Word | In this class it means |
# |---|---|
# | **The thing vs receipt** | The token *is* the promise, or it is a stub for a coat. |
# | **Redemption** | Stub → coat (cookie, minutes). Honor one before you write. |
# | **Netting** | Erase an equal cycle. Uneven leftover still owes. |
# | **CBDC** | Central-bank digital dollar. Your ERC-20 is not this. |

# %% [markdown]
# Handbook § S9 (coat check) and § S10 (triangle of 10, leftover 5).

# %%
# ===== claim (edit) =====
token_is = "receipt"  # receipt | the-asset
stands_for = "5 minutes of tutoring the team will actually sit for"
redeemer = "any listed teammate"
redeem_how = "burn 1 EAGE, start a 5-minute timer, show up"
if_we_ghost = "holders have a grade problem, not a court claim — we say that out loud"
in_class_redemption = "tx or photo: PASTE"

print("Our token is a", token_is, "for:", stands_for)
print("Redeem:", redeemer, "|", redeem_how)
print("If we disappear:", if_we_ghost)
print("Evidence:", in_class_redemption)

# %%
# Edit this matrix from Week 4, or keep the triangle and label "instructor example".
label = "instructor example"  # or "live class trades"
names = ["A", "B", "C"]
owes = [
    [0, 10, 0],
    [0, 0, 10],
    [10, 0, 0],
]
print(label)
print("before", owes)

m = [row[:] for row in owes]
m[0][1] -= 10
m[1][2] -= 10
m[2][0] -= 10
print("after set-off of 10", m)

cbdc_side = "help / kill / mixed -- pick one and write 4 sentences"
print("CBDC take:", cbdc_side)

# %% [markdown]
# ## Teen version of the CBDC question
#
# If the government hands everyone a perfect school-ID dollar app,
# do you still need EAGE for tutoring — or do people just Venmo?
#
# There is no holy answer. There is a side + a reason.

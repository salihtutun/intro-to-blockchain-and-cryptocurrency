# %% [markdown]
# # A7 — Design memo workshop (2,000 words)
#
# This notebook does **not** write the memo for you. It builds an **outline
# with your evidence** so you stop staring at a blank page.
#
# Required headings (use them):
# 1. Problem and community
# 2. Mechanism
# 3. Circulation evidence
# 4. What the market revealed
# 5. Unbundle the stack  ← the MIT section; this must be new writing
# 6. What broke
# 7. Go / partner / pass
# 8. Sources (co-op or Sarafu, one Naranjo result, one MIT/BIS idea)
#
# No hype. No price prediction. Numbers beat adjectives.

# %% [markdown]
# ## Words we use today
#
# Read this once. If a later cell uses the word, come back here.
#
# | Word | In this class it means |
# |---|---|
# | **Unbundle** | Database vs chain, registrar vs consensus, token vs escrow — your words. |
# | **Circulation evidence** | Hashes, stranger holder, pool quote. Not adjectives. |
# | **Go / partner / pass** | One verb. Pass with evidence is an A-level ending. |

# %% [markdown]
# Handbook § S13 plus the week of the claim you are defending.
# Section 5 (unbundle) must be new writing even if the team shares logs.

# %%
# Paste receipts, then print a skeleton you type over in Google Docs.

problem = "..."
community = "..."
mechanism = "minter / cap / claim ..."
tx_hashes = ["0x...", "0x..."]  # 3+ real
pool = {"x_team": 0, "y_classusd": 0, "external_swap": "0x..."}
broke = "one true story"
recommendation = "go | partner | pass"  # pick ONE verb
why_fintech = "one paragraph: copy, partner for the rail, or ignore"

unbundle = {
    "needed_a_chain": "yes/no — why",
    "needed_consensus": "yes/no — we rented Sepolia / we needed PoW / ...",
    "needed_a_token": "yes/no — escrow might have been enough because ...",
}

sources = {
    "coop_or_sarafu": "Sweeney/Krugman or Sarafu — what you used",
    "naranjo": "PoW tamper / AMM slippage / depeg number",
    "mit_or_bis": "database view / coordination / money flower / unbundle",
}

print("# Design memo skeleton\n")
print("## 1 Problem and community\n", community, "\n", problem)
print("## 2 Mechanism\n", mechanism)
print("## 3 Circulation\n", tx_hashes, pool)
print("## 4 Market\n (price, depth, who traded — use A4 numbers)")
print("## 5 Unbundle\n", unbundle)
print("## 6 Broke\n", broke)
print("## 7 Recommendation\n", recommendation, why_fintech)
print("## 8 Sources\n", sources)
print("\nWord-count trick: if section 5 is shorter than section 1, you are not done.")

# %% [markdown]
# ## Sample unbundle (paraphrase, don't paste)
#
# We did not need a new Bitcoin. We needed a shared list of balances and
# a posted mint rule. A spreadsheet plus the instructor as registrar would
# have cleared tutoring IOUs. The token + AMM gave a public price. That
# helped Week 4. It did not create the tutoring. Consensus was rented from
# the testnet. Escrow (teacher holds CLASSUSD until notes arrive) would have
# fixed trade-fails without an ERC-20.
#
# If your section 5 is "blockchain is the future," start over.
